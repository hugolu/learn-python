# %% [markdown]
# # 彻底解决matplotlib中文乱码问题
# 出处： http://blog.csdn.net/dgatiger/article/details/50414549

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
#matplotlib.use('qt4agg') 

from matplotlib.font_manager import *  
myfont = FontProperties(fname='/Users/ruwang/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/matplotlib/mpl-data/fonts/ttf/simhei.ttf') 
#matplotlib.rcParams['font.sans-serif'] = ['SimHei']   
#matplotlib.rcParams['font.family']='sans-serif'  

#解决负号'-'显示为方块的问题  
matplotlib.rcParams['axes.unicode_minus'] = False   
plt.plot([-1,2,-5,3])  
plt.title(u'中文',fontproperties=myfont)

# %% [markdown]
# - 必须明确指定字形

# %%
from pandas import DataFrame
df = DataFrame(np.random.randn(16).reshape((4,4)), columns=[u'第一', u'第二', u'第三', u'第四'])
df.plot()

# %% [markdown]
# - 然而，legend 无法指定字形
